# %% [markdown]
# # Task 1 – Data Scraping & Collection
#
#
#
# ---
#
# ## 📖 Overview
#
# In this task, we’ll extract raw data from Telegram channels and populate our data lake with unaltered JSON and image files. This “source of truth” will serve as the foundation for all downstream transformation and enrichment.
#
# ---
#
# ## Objectives
#
# 1. **Telegram Scraping**
#    - Connect to the Telegram API (via Telethon or similar).
#    - Extract messages from targeted Ethiopian medical-business channels.
# 2. **Image Collection**
#    - Download any media (images) attached to those messages.
# 3. **Data Lake Ingestion**
#    - Store all raw JSON payloads under `data/raw/telegram_messages/YYYY-MM-DD/<channel>.json`.
#    - Save images under `data/raw/images/YYYY-MM-DD/<channel>/<message_id>.jpg`.
# 4. **Logging & Reliability**
#    - Log channel names, timestamps, and success/failure for each scrape.
#    - Handle errors (e.g., rate limits) gracefully and retry where appropriate.
#
# ---
#
# ## 🔗 Channel Sources
#
# - **Chemed Cosmetics**: `https://t.me/lobelia4cosmetics`
# - **Tikvah Pharma**: `https://t.me/tikvahpharma`
# - _…plus additional channels from_ [et.tgstat.com/medicine](https://et.tgstat.com/medicine) :contentReference[oaicite:0]{index=0}
#
# ---

# %%
# 2️⃣ Load your .env so that the script sees the same config
from dotenv import load_dotenv
from pathlib import Path
import os

project_root = Path(r"C:\Users\ABC\Desktop\10Acadamy\week_7\Shipping-a-Data-Product")
load_dotenv(dotenv_path=project_root / ".env")

# Optional: verify channels are loaded
print("TEXT_CHANS =", os.getenv("TELEGRAM_TEXT_CHANNELS"))
print("IMAGE_CHANS =", os.getenv("TELEGRAM_IMAGE_CHANNELS"))
# Out:
# TEXT_CHANS = lobelia4cosmetics,tikvahpharma,CheMed123
# IMAGE_CHANS = lobelia4cosmetics,CheMed123

# %% [markdown]
# ## Load configuration from `.env`
#
# Use the `python-dotenv` package to load your environment variables from the project’s `.env` file so that your script can pick up the same API keys and channel settings every time it runs.

# %%
import nest_asyncio
nest_asyncio.apply()
print("nest_asyncio applied — you can now use sync Telethon in Jupyter!")
# Out:
# nest_asyncio applied — you can now use sync Telethon in Jupyter!

# %%
# 2️⃣ Load your .env so that the script sees the same config
from dotenv import load_dotenv
from pathlib import Path
import os

project_root = Path(r"C:\Users\ABC\Desktop\10Acadamy\week_7\Shipping-a-Data-Product")
load_dotenv(dotenv_path=project_root / ".env")

# Optional: verify channels are loaded
print("TEXT_CHANS =", os.getenv("TELEGRAM_TEXT_CHANNELS"))
print("IMAGE_CHANS =", os.getenv("TELEGRAM_IMAGE_CHANNELS"))
# Out:
# TEXT_CHANS = lobelia4cosmetics,tikvahpharma,CheMed123
# IMAGE_CHANS = lobelia4cosmetics,CheMed123

# %% [markdown]
# ##  Run the scraper as a standalone process
#
# To avoid conflicts with any existing event loops (e.g., in Jupyter), launch your scraper script in its own Python process:

# %%
project_root = Path(r"C:\Users\ABC\Desktop\10Acadamy\week_7\Shipping-a-Data-Product")
# 3️⃣ Run the scraper as its own process (no event‐loop clash)
# !python C:\Users\ABC\Desktop\10Acadamy\week_7\Shipping-a-Data-Product\src\scrapper.py
# Out:
# C:\Users\ABC\Desktop\10Acadamy\week_7\Shipping-a-Data-Product\src\scrapper.py:49: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().strftime("%Y-%m-%d")
# 2025-07-13 09:16:05,016 INFO Connecting to 149.154.167.92:443/TcpFull...
# 2025-07-13 09:16:05,211 INFO Connection to 149.154.167.92:443/TcpFull complete!
# 2025-07-13 09:16:06,546 INFO Connected to Telegram for text scraping
# 2025-07-13 09:16:06,546 INFO Fetching up to 100 messages from lobelia4cosmetics
# 2025-07-13 09:16:07,844 INFO Saved 100 messages to data\raw\telegram_messages\2025-07-13\lobelia4cosmetics.json
# 2025-07-13 09:16:07,844 INFO Fetching up to 100 messages from tikvahpharma
# 2025-07-13 09:16:09,995 INFO Saved 100 messages to data\raw\telegram_messages\2025-07-13\tikvahpharma.json
# 2025-07-13 09:16:09,995 INFO Fetching up to 100 messages from CheMed123
# 2025-07-13 09:16:11,199 INFO Saved 76 messages to data\raw\telegram_messages\2025-07-13\CheMed123.json
# 2025-07-13 09:16:11,200 INFO Disconnecting from 149.154.167.92:443/TcpFull...
# 2025-07-13 09:16:11,203 INFO Disconnection from 149.154.167.92:443/TcpFull complete!
# 2025-07-13 09:16:11,223 INFO Connecting to 149.154.167.92:443/TcpFull...
# 2025-07-13 09:16:11,356 INFO Connection to 149.154.167.92:443/TcpFull complete!
# 2025-07-13 09:16:12,485 INFO Connected to Telegram for image scraping
# 2025-07-13 09:16:12,486 INFO Downloading up to 50 images from lobelia4cosmetics
# 2025-07-13 09:16:12,834 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:15,167 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:17,030 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:17,474 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:18,643 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:19,326 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:20,908 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:21,424 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:22,031 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:23,482 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:25,020 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:25,683 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:26,867 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:28,020 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:28,564 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:29,684 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:32,574 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:36,810 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:37,732 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:38,165 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:38,826 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:40,848 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:41,308 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:41,747 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:42,174 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:43,080 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:43,738 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:44,375 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:45,907 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:46,235 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:48,045 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:49,666 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:51,019 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:52,720 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:54,138 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:55,860 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:56,530 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:57,703 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:58,492 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:16:58,998 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:00,053 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:01,051 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:01,641 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:02,190 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:02,793 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:05,248 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:07,551 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:08,113 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:10,153 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:10,631 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:12,321 INFO Downloaded 50 images to data\raw\telegram_images\2025-07-13\lobelia4cosmetics
# 2025-07-13 09:17:12,321 INFO Downloading up to 50 images from CheMed123
# 2025-07-13 09:17:12,791 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:13,743 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:15,592 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:16,900 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:17,953 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:19,164 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:21,455 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:23,192 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:25,590 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:27,288 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:29,582 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:31,192 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:32,266 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:33,474 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:35,376 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:36,772 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:39,075 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:41,277 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:43,929 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:46,092 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:48,603 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:50,104 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:51,897 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:54,420 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:56,528 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:58,785 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:17:59,982 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:01,657 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:02,682 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:04,840 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:06,870 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:08,638 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:09,575 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:11,147 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:12,771 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:15,637 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:17,914 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:19,880 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:21,673 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:23,681 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:25,776 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:26,816 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:28,425 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:30,563 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:31,996 INFO Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-13 09:18:34,628 INFO Downloaded 45 images to data\raw\telegram_images\2025-07-13\CheMed123
# 2025-07-13 09:18:34,629 INFO Disconnecting from 149.154.167.92:443/TcpFull...
# 2025-07-13 09:18:34,630 INFO Disconnection from 149.154.167.92:443/TcpFull complete!

# %% [markdown]
# ## Verify that the JSON and JPG files landed under `data/raw`
#
# After running the scraper, we can programmatically check that our raw data files exist in the expected directories:

# %%
# 4️⃣ Verify that the JSON and JPG files landed under data/raw
import glob, json
from pprint import pprint

msg_files = sorted(glob.glob("data/raw/telegram_messages/*/*.json"))
img_files = sorted(glob.glob("data/raw/telegram_images/*/*/*.jpg"))

print(f"Found {len(msg_files)} JSON files:")
pprint(msg_files)
print(f"\nFound {len(img_files)} image files:")
pprint(img_files)

# 5️⃣ Peek at one JSON record
if msg_files:
    with open(msg_files[0], encoding="utf-8") as f:
        sample = json.load(f)
    print("\nSample record:")
    pprint(sample[0])
# Out:
# Found 3 JSON files:
# ['data/raw/telegram_messages\\2025-07-13\\CheMed123.json',
#  'data/raw/telegram_messages\\2025-07-13\\lobelia4cosmetics.json',
#  'data/raw/telegram_messages\\2025-07-13\\tikvahpharma.json']
#
# Found 95 image files:
# ['data/raw/telegram_images\\2025-07-13\\CheMed123\\33.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\34.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\38.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\39.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\40.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\41.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\43.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\44.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\45.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\46.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\48.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\49.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\50.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\52.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\53.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\55.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\56.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\58.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\59.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\60.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\64.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\67.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\70.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\71.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\74.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\75.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\76.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\77.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\78.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\79.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\80.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\81.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\82.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\85.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\86.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\87.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\88.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\90.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\91.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\92.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\93.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\94.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\95.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\96.jpg',
#  'data/raw/telegram_images\\2025-07-13\\CheMed123\\97.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18486.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18487.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18488.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18489.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18490.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18491.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18492.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18493.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18494.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18495.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18496.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18497.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18498.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18499.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18500.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18501.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18502.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18503.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18504.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18505.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18506.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18507.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18508.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18509.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18510.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18511.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18512.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18513.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18514.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18515.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18516.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18517.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18518.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18519.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18520.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18521.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18522.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18523.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18524.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18525.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18526.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18527.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18528.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18529.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18530.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18531.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18532.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18533.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18534.jpg',
#  'data/raw/telegram_images\\2025-07-13\\lobelia4cosmetics\\18535.jpg']
#
# Sample record:
# {'_': 'Message',
#  'date': '2023-02-10 12:23:06+00:00',
#  'edit_date': '2023-03-11 15:41:17+00:00',
#  'edit_hide': True,
#  'effect': None,
#  'entities': [{'_': 'MessageEntityBold', 'length': 8, 'offset': 2},
#               {'_': 'MessageEntityBold', 'length': 6, 'offset': 178}],
#  'factcheck': None,
#  'forwards': 1,
#  'from_boosts_applied': None,
#  'from_id': None,
#  'from_scheduled': False,
#  'fwd_from': {'_': 'MessageFwdHeader',
#               'channel_post': None,
#               'date': '2023-02-10 12:22:53+00:00',
#               'from_id': {'_': 'PeerUser', 'user_id': 339373129},
#               'from_name': None,
#               'imported': False,
#               'post_author': None,
#               'psa_type': None,
#               'saved_date': None,
#               'saved_from_id': None,
#               'saved_from_msg_id': None,
#               'saved_from_name': None,
#               'saved_from_peer': None,
#               'saved_out': False},
#  'grouped_id': None,
#  'id': 97,
#  'invert_media': False,
#  'legacy': False,
#  'media': {'_': 'MessageMediaPhoto',
#            'photo': {'_': 'Photo',
#                      'access_hash': -3762850727453317604,
#                      'date': '2023-02-10 12:22:53+00:00',
#                      'dc_id': 4,
#                      'file_reference': "b'\\x02`\\xfa\\xe8\\xe2\\x00\\x00\\x00ahsO!(\\x83*\\xe0\\x9a\\xc4_\\xb5\\x7f\\xb7o\\xc2\\xd4\\x82\\xd8\\xe2'",
#                      'has_stickers': False,
#                      'id': 5994407541049769840,
#                      'sizes': [{'_': 'PhotoStrippedSize',
#                                 'bytes': "b'\\x01((\\xd7;\\xb208\\xefN\\xa2\\xaa\\xdd\\\\\\x08\\xe3eG\\xc4\\x98\\xe3\\x8c\\xe2\\x816\\x96\\xe4\\xe6DW\\x08X\\x06# "
#                                          '{Uy\\xafUx\\x8b\\xe6>\\xbd\\xab6I\\xdevG\\x94\\x8c\\xaf@\\xa2\\x8d\\xdc\\xf3\\xd3\\xb5RFS\\xa8\\xf6D\\x8f#H\\xd9s\\x93E7\\xad\\x15G;\\xbb/^I4jH\\x1bc\\x1f\\xc4*\\x87\\x12\\x01\\xcf\\x06\\xac\\xdd\\t\\xee\\x8b\\xc0\\xa3\\x18\\xc1\\xc1\\xe3\\x14\\x96\\x962\\xacL$\\x01[<\\x0c\\xe4\\x1f\\xadBgL\\xe1}H|\\x91\\xfeA\\xa3\\xc9\\x03\\xa7\\xf5\\xa9]Z3\\x87\\x8c\\x01\\xeb\\x8an\\xf1\\xe8?*\\xa3\\x11\\x856\\x8fo\\xa5\\x14\\xa5\\xf21\\xb5h\\xa6C\\xb1\\xad\\xe5\\xaf\\x9b\\xe6\\x7f\\x166\\xfe\\x14\\xfa(\\xac\\xce\\xe1\\xac\\xa1\\xd4\\x86\\x00\\x83\\xd8\\xd59\\xac\\xbf\\x8a/\\xfb\\xe4\\xd1E;\\x93(\\xa9nSe(\\xc40 '
#                                          "\\x8e\\xd4QEY\\xc8\\xf4g'",
#                                 'type': 'i'},
#                                {'_': 'PhotoSize',
#                                 'h': 320,
#                                 'size': 20074,
#                                 'type': 'm',
#                                 'w': 320},
#                                {'_': 'PhotoSize',
#                                 'h': 800,
#                                 'size': 67251,
#                                 'type': 'x',
#                                 'w': 800},
#                                {'_': 'PhotoSizeProgressive',
#                                 'h': 1080,
#                                 'sizes': [9789, 26401, 43844, 59784, 84627],
#                                 'type': 'y',
#                                 'w': 1080}],
#                      'video_sizes': []},
#            'spoiler': False,
#            'ttl_seconds': None},
#  'media_unread': False,
#  'mentioned': False,
#  'message': '⚠️Notice!\n'
#             'Dear esteemed customers,\n'
#             'Due to four-day motorbike movement restrictions, we have limited '
#             'our services to matchmaking,drug information, and medical '
#             'consultation only.\n'
#             '\n'
#             'N.B. \n'
#             '🔅We will make deliveries for those for whom the medications are '
#             'urgent.\n'
#             '🔅You can book deliveries starting from Monday, February 13, 2023',
#  'noforwards': False,
#  'offline': False,
#  'out': False,
#  'paid_message_stars': None,
#  'peer_id': {'_': 'PeerChannel', 'channel_id': 1627056354},
#  'pinned': False,
#  'post': True,
#  'post_author': None,
#  'quick_reply_shortcut_id': None,
#  'reactions': {'_': 'MessageReactions',
#                'can_see_list': False,
#                'min': False,
#                'reactions_as_tags': False,
#                'recent_reactions': [],
#                'results': [{'_': 'ReactionCount',
#                             'chosen_order': None,
#                             'count': 2,
#                             'reaction': {'_': 'ReactionEmoji',
#                                          'emoticon': '👍'}}],
#                'top_reactors': []},
#  'replies': None,
#  'reply_markup': None,
#  'reply_to': None,
#  'report_delivery_until_date': None,
#  'restriction_reason': [],
#  'saved_peer_id': None,
#  'silent': False,
#  'ttl_period': None,
#  'via_bot_id': None,
#  'via_business_bot_id': None,
#  'video_processing_pending': False,
#  'views': 1183}

# %%
from collections import Counter
import os, glob
# 6️⃣ Count images per channel
img_paths = glob.glob("data/raw/telegram_images/*/*/*.jpg")
# the channel name is the second‐to-last folder in the path
channels = [os.path.basename(os.path.dirname(p)) for p in img_paths]
counts = Counter(channels)

print("Images per channel:")
for channel, cnt in counts.items():
    print(f"  {channel}: {cnt}")
# Out:
# Images per channel:
#   CheMed123: 45
#   lobelia4cosmetics: 50
